# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import model_implementation_pipeline as mip
import features_transformation_pipeline as ftp
from scipy.sparse import hstack

import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1.Creating Inference data from existing raw dataset

# %%
project_data = pd.read_csv('/Users/shubhamshivendra/workspace/Project/Donors Choose/Data Sets/train_data.csv', nrows=60000)
resource_data = pd.read_csv('/Users/shubhamshivendra/workspace/Project/Donors Choose/Data Sets/resources.csv')

# %%
resource_data.columns
# Out:
# Index(['id', 'description', 'quantity', 'price'], dtype='object')

# %%
project_data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'teacher_id', 'teacher_prefix', 'school_state',
#        'project_submitted_datetime', 'project_grade_category',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_title', 'project_essay_1', 'project_essay_2',
#        'project_essay_3', 'project_essay_4', 'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved'],
#       dtype='object')

# %%
new_data = project_data[project_data['id'] == 'p001713']

# %%
# dropping target variable (in generalized we don't have target variable)
project_data = project_data.drop('project_is_approved', axis = 1)

# %%
generalized_data = project_data.iloc[59970:59999]

# %%
generalized_data.shape
# Out:
# (29, 16)

# %%
def feature_transform(data):
    scaler = pickle.load(open('/Users/shubhamshivendra/workspace/Project/Donors Choose/Data Sets/scaler.pkl', 'rb'))
    num = scaler.transform(data[scaler.feature_names_in_])
    ohe = pickle.load(open('/Users/shubhamshivendra/workspace/Project/Donors Choose/Data Sets/ohe.pkl', 'rb'))
    cat = ohe.transform(data[ohe.feature_names_in_])
    essay_vectorize = ftp.avg_word_2vec(data)
    data_new = hstack((num, cat, essay_vectorize)).tocsr()
    return data_new

# %%
def predict_score_inf(project_data, resource_data):
    new_data = ftp.preprocess_data(project_data, resource_data)
    df = feature_transform(new_data)
    log = pickle.load(open('/Users/shubhamshivendra/workspace/Project/Donors Choose/Data Sets/LogisticRegression.pkl', 'rb'))
    y_train_pred = mip.batch_pred(log, df)
    final = mip.predict_with_best_t(y_train_pred, 0.8347440976017594)
    return final

# %%
predict_score_inf(new_data, resource_data)
# Out:
# [1]

# %%
new_data.dtypes
# Out:
# Unnamed: 0                                       int64
# id                                              object
# teacher_id                                      object
# teacher_prefix                                  object
# school_state                                    object
# project_submitted_datetime                      object
# project_grade_category                          object
# project_subject_categories                      object
# project_subject_subcategories                   object
# project_title                                   object
# project_essay_1                                 object
# project_essay_2                                 object
# project_essay_3                                 object
# project_essay_4                                 object
# project_resource_summary                        object
# teacher_number_of_previously_posted_projects     int64
# project_is_approved                              int64
# dtype: object

# %%
predicted_df = pd.DataFrame([predict_score_inf(generalized_data, resource_data)]).T
predicted_df.columns = ['Predicted']
predicted_df
# Out:
#     Predicted
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# 5           0
# 6           1
# 7           1
# 8           1
# 9           0
# 10          1
# 11          0
# 12          1
# 13          0
# 14          0
# 15          1
# 16          0
# 17          0
# 18          1
# 19          1
# 20          1
# 21          0
# 22          1
# 23          0
# 24          0
# 25          1
# 26          1
# 27          0
# 28          1

# %%
print(generalized_data.shape)
print(predicted_df.shape)
# Out:
# (29, 16)
# (29, 1)

# %%
# Appending the dataframe generalized data
final =  pd.concat([generalized_data.reset_index(), predicted_df], axis=1, ignore_index= True)

# %%
final
# Out:
#        0       1        2                                 3     4   5   \
# 0   59970   14151  p189783  b9c26df385fddfca0e5ea24c9af0f6b7   Ms.  NY
# 1   59971  150029  p033189  bd2049000d07f47146451280b21b7917  Mrs.  NJ
# 2   59972   55124  p107197  6ce9df9062b388c29cca6a6ee68bd7bc  Mrs.  NY
# 3   59973   35974  p179016  c96d79def0bba46c7ba963602cb7e773   Ms.  CA
# 4   59974  103193  p206960  546cf86b33fc9d7d002a97a462afc9f7   Mr.  CA
# 5   59975  129981  p151636  2374ad2b2caa504cfd586c27723106ca  Mrs.  MD
# 6   59976  131219  p014597  a018433a7d294d926ee9cefd177f5069   Ms.  IL
# 7   59977  121798  p239818  e88140b2ef27cfac193612585282dcb5  Mrs.  ND
# 8   59978  176693  p003832  98687bf0c7adeabcc749ec92702497b4  Mrs.  IL
# 9   59979   58729  p056491  22656e540653abc605910daca1548065   Ms.  MN
# 10  59980   71893  p085755  85742384397ed52665194a80dbe57b56   Ms.  MA
# 11  59981   71603  p217281  70f1bab287e9edc77e191b161c2c85e5  Mrs.  MO
# 12  59982  130465  p066073  4106216f7d4c116dcdc83944130d6201   Ms.  CA
# 13  59983  138565  p195047  d287f40f6e99ea5643dea02d3563a352   Ms.  TX
# 14  59984   47105  p052462  9154d5a7f43daed71fd36482a219a1ba   Ms.  CA
# 15  59985  142507  p211258  43b9a5e6bb9a7747401143ffb080aba8  Mrs.  MA
# 16  59986    1662  p139029  2056ab5177f8e9fac1eeb05af19d5f6a   Mr.  AZ
# 17  59987  156951  p142068  285f82e8600504d37d7f8bcbdb03478e   Ms.  NY
# 18  59988  157404  p040714  f5fb3669a01bbc49a2e6b0e8cbae701b  Mrs.  NY
# 19  59989   22545  p058955  d779d00250cdcaaa55af68685eb4d91c  Mrs.  AZ
# 20  59990    8787  p221163  4169e20fbb3c2b2157b723f7b7e33271   Ms.  CA
# 21  59991    7410  p041479  fbbff1ed79fe7f38af75a1c6dd494a2d   Ms.  CA
# 22  59992    8296  p033502  b6fe546c0c5bdee237a4f776c559f7a8   Ms.  CA
# 23  59993   59303  p107799  de0e657854d24ccb9e97faeb93cefb32  Mrs.  PA
# 24  59994  154524  p052607  ca7ad40142411a2984042d1b01df24e4   Ms.  SC
# 25  59995  145400  p038961  76117de91a5ab98aa6dd8159d518dcea  Mrs.  WA
# 26  59996  135454  p188107  2fe6084fb0b9c8bd4ee5d8997ffc35b4  Mrs.  NY
# 27  59997  108715  p129217  bfe436998c8fc61f959a233ce9d99bf9  Mrs.  MI
# 28  59998   77286  p182940  c07b0a8cfc429dc73f048b3c481b73bb   Ms.  GA
#
#                      6              7                                      8   \
# 0   2016-12-29 14:38:10     Grades 6-8                       Music & The Arts
# 1   2017-01-20 07:21:25  Grades PreK-2  Literacy & Language, Applied Learning
# 2   2016-08-08 16:32:20     Grades 3-5       Math & Science, Music & The Arts
# 3   2016-09-14 21:22:47     Grades 6-8  History & Civics, Literacy & Language
# 4   2016-08-30 12:26:41     Grades 6-8       Math & Science, History & Civics
# 5   2016-06-24 12:03:04  Grades PreK-2       Applied Learning, Math & Science
# 6   2016-06-21 11:05:54     Grades 6-8  Literacy & Language, History & Civics
# 7   2016-08-29 09:53:05     Grades 3-5                       Music & The Arts
# 8   2016-11-29 14:58:16     Grades 3-5                         Math & Science
# 9   2017-02-22 21:55:11     Grades 3-5       Math & Science, History & Civics
# 10  2016-11-17 11:20:57  Grades PreK-2                    Literacy & Language
# 11  2016-08-06 10:36:17  Grades PreK-2                        Health & Sports
# 12  2016-11-10 16:46:10  Grades PreK-2                  Warmth, Care & Hunger
# 13  2016-10-06 13:23:05     Grades 3-5       Math & Science, Music & The Arts
# 14  2016-11-27 20:58:32     Grades 3-5     Literacy & Language, Special Needs
# 15  2017-01-13 12:52:11  Grades PreK-2    Literacy & Language, Math & Science
# 16  2016-08-09 15:27:42    Grades 9-12                         Math & Science
# 17  2017-02-15 20:37:44    Grades 9-12                       History & Civics
# 18  2016-06-21 14:58:29     Grades 3-5     Literacy & Language, Special Needs
# 19  2016-08-09 14:11:52  Grades PreK-2                    Literacy & Language
# 20  2016-07-20 08:25:27  Grades PreK-2        Applied Learning, Special Needs
# 21  2016-10-04 12:33:00    Grades 9-12                          Special Needs
# 22  2016-08-24 17:08:54     Grades 6-8                    Literacy & Language
# 23  2016-10-03 15:45:51     Grades 3-5       Applied Learning, Math & Science
# 24  2017-01-19 17:29:39    Grades 9-12                         Math & Science
# 25  2016-11-01 22:50:45  Grades PreK-2  Applied Learning, Literacy & Language
# 26  2017-04-03 20:09:25     Grades 3-5    Literacy & Language, Math & Science
# 27  2016-08-04 14:06:56     Grades 3-5                        Health & Sports
# 28  2016-12-13 10:13:18     Grades 3-5                    Literacy & Language
#
#                                            9   \
# 0                             Performing Arts
# 1                      ESL, Early Development
# 2          Environmental Science, Visual Arts
# 3   History & Geography, Literature & Writing
# 4      Health & Life Science, Social Sciences
# 5          College & Career Prep, Mathematics
# 6       Literature & Writing, Social Sciences
# 7                                       Music
# 8                            Applied Sciences
# 9                Mathematics, Social Sciences
# 10                                   Literacy
# 11                          Health & Wellness
# 12                      Warmth, Care & Hunger
# 13                   Mathematics, Visual Arts
# 14                    Literacy, Special Needs
# 15                      Literacy, Mathematics
# 16                                Mathematics
# 17                        History & Geography
# 18        Literature & Writing, Special Needs
# 19                                   Literacy
# 20       College & Career Prep, Special Needs
# 21                              Special Needs
# 22                       Literature & Writing
# 23   Community Service, Environmental Science
# 24                                Mathematics
# 25                Early Development, Literacy
# 26          Literature & Writing, Mathematics
# 27                          Health & Wellness
# 28                                   Literacy
#
#                                                    10  \
# 0                           Middle School Drum Circle
# 1                        A Little Drama in Our Lives!
# 2                             Pretty Paper Projects!!
# 3           Pen to Paper Makes for Prepared Scholars!
# 4   Engaging Native American youth with technology...
# 5                            Learning Beyond Our City
# 6        Helping 6th Graders Become Informed Citizens
# 7              Tubano Drums for Longfellow Elementary
# 8                                        Generation Z
# 9                              Flexible Seating Table
# 10                             For the Love of Books!
# 11                     Wiggle, Wiggle, Wiggle, Part 2
# 12                        Backpacks for All Students!
# 13         Young Architects and Engineers in Training
# 14                      Flexible Learning Environment
# 15       Chromebooks Create \r\nLearning Through Play
# 16                       Geometric Proofs Instruction
# 17                      One tool to help 175 students
# 18                  Help Us Start The Year Off Right!
# 19  The More That You Read, the More That You'll K...
# 20                            Choose a Seat and Learn
# 21                                   Printer Supplies
# 22  High-Interest Novels Needed So Students Can Ac...
# 23                             Recording Our Learning
# 24                                  Response Clickers
# 25                      Help Our Kinder Eaglets Soar!
# 26                        Warm and Cozy Reading Area!
# 27                               Striving for Balance
# 28              Comfy and Cozy in the Reading Center!
#
#                                                    11  \
# 0   Our school is populated with children from all...
# 1   My class is made up of 15 children and 3-4 stu...
# 2   \r\nMy students are very poor students who str...
# 3   My phenomenal students come from diverse  back...
# 4   These are all Native American students from un...
# 5   Our school is faced with a tight spending budg...
# 6   Sixth grade is a year of many changes for stud...
# 7   I teach first through fifth grade almost all o...
# 8   School-wide ninety-four percent of our student...
# 9   These students are the most thoughtful and giv...
# 10  Learning to read is an exciting time in a youn...
# 11  Most of the students come from lower income ba...
# 12  Our school is a small elementary school in Eas...
# 13  Art is the highlight of many students' day. My...
# 14  As a resource teacher, I service a diverse gro...
# 15  I am privileged to be a second grade teacher o...
# 16  Accelerated Learning Center is an alternative ...
# 17  Why should budget cuts affect our children’s f...
# 18  My students come from a low income area where ...
# 19  I have a wonderful class of bright, inquisitiv...
# 20  My students are kindergarten, ages 5 & 6. We a...
# 21  My students receive special education services...
# 22  My students get so frustrated by comprehension...
# 23  The children coming into my class each day are...
# 24  The students I teach are amazing. They come in...
# 25  I am a first year LAP (Learning Assistance Pro...
# 26  Have you ever walked the footsteps of a child ...
# 27  My students live in a high poverty, rural comm...
# 28  I always tell my students, school is their hom...
#
#                                                    12   13   14  \
# 0   The drum is a perfect instrument for middle sc...  NaN  NaN
# 1   The furniture that I have chosen will help pro...  NaN  NaN
# 2   This project will allow my students to create ...  NaN  NaN
# 3   These materials will allow my students to have...  NaN  NaN
# 4   Our students are consistently asking for bette...  NaN  NaN
# 5   Having these laptops and tablet will allow us ...  NaN  NaN
# 6   This donation will provide students with a res...  NaN  NaN
# 7   Every year in music class we spend time workin...  NaN  NaN
# 8   Beginning Computer Science Week, using a Googl...  NaN  NaN
# 9   Flexible seating is motivating for students! I...  NaN  NaN
# 10  The book organizing shelves will be a huge ass...  NaN  NaN
# 11  I always tell me students to shoot for the moo...  NaN  NaN
# 12  Many students in my class cannot afford backpa...  NaN  NaN
# 13  My students are excited when it is their art d...  NaN  NaN
# 14  Research has shown that activity helps the bra...  NaN  NaN
# 15  The digitalized age is upon us and young stude...  NaN  NaN
# 16  The state of Arizona created a new standardize...  NaN  NaN
# 17  My students & I will use this 2 in 1 laptop as...  NaN  NaN
# 18  Your donation could help my classroom charge t...  NaN  NaN
# 19  I would love to be able to utilize these Ipads...  NaN  NaN
# 20  I'm a bit of a wiggler and need constant movem...  NaN  NaN
# 21  We were donated a printer, now we just have to...  NaN  NaN
# 22  This school year, my 7th graders will be readi...  NaN  NaN
# 23  Our students will begin their second year emba...  NaN  NaN
# 24  The clickers will allow the students to answer...  NaN  NaN
# 25  Both the Alphabet Sounds Photo Library and the...  NaN  NaN
# 26  My students have enjoyed having alternate seat...  NaN  NaN
# 27  After completing a unit about balanced lifesty...  NaN  NaN
# 28  My students will be able to sit in the reading...  NaN  NaN
#
#                                                    15  16  17
# 0   My students need 10 djembes to be able to part...  13   1
# 1   My students need dramatic play furniture to he...   5   0
# 2   My students need large colored paper rolls for...   5   1
# 3   My students need basic supplies to begin the n...   3   1
# 4   My students need technology (tablets and a pro...   0   0
# 5   My students need new technology to prepare the...   3   0
# 6   My students need to learn more about current e...   0   1
# 7   My students need Remo Tubano Drums so they can...   0   1
# 8   My students need a 3doodler Start Full Educati...   4   1
# 9   My students need flexible seating to collabora...   1   0
# 10  My students need two mobile book organizer she...   4   1
# 11  My students need stools, cushions, flexibility...   4   0
# 12  My students need backpacks to store and transp...   1   1
# 13  My students need Magnatiles to enrich their le...   2   0
# 14  My students need a teaching cart for a flexibl...   1   0
# 15  My students need access to today's innovative ...   1   1
# 16  My students need help with passing the new Az ...   0   0
# 17     My students need a 2 in 1 laptop for class use   2   0
# 18  My students need a charging station for the iP...   3   1
# 19  My students need the ability to explore books ...   0   1
# 20  My students need flexible seating. Flexible se...  14   1
# 21  My students need to print or make copies of as...   2   0
# 22  My students need class copies of The Giver and...   7   1
# 23  My students need a video recorder to document ...   1   0
# 24  My students need interactive clickers so I can...   1   0
# 25  My students need multi-sensory hands on materi...   0   1
# 26  My students need a coordinated, warm and invit...   4   1
# 27  My students need flexible seating, indoor fitn...   0   0
# 28  My students need a carpet and bean bags in the...   0   1
